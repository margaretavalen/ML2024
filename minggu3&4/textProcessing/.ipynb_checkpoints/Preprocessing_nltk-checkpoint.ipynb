# %% [markdown]
# Preprocessing
# ===
# ***Margareta Valencia (A11.2022.14704)***
#
# ---

# %% [markdown]
# # load library

# %%
import re
import string
import time
from copy import deepcopy

# %% [markdown]
# # load dataset
#
# Dataset ini menggunakan twitter data dan reddit data.
# Kali ini saya akan menggunakan twitter data terlebih dahulu

# %%
import pandas as pd

# %%
df = pd.read_csv('Data_Twitter.csv', delimiter='\t')

# %%
df.head()
# Out:
#                         Date           User  \
# 0  2022-03-31 14:32:04+00:00  pikobar_jabar
# 1  2022-03-31 09:26:00+00:00     inewsdotid
# 2  2022-03-31 05:02:34+00:00      vdvc_talk
# 3  2022-03-30 14:23:10+00:00  pikobar_jabar
# 4  2022-03-30 11:28:57+00:00      tvOneNews
#
#                                                Tweet  sentiment
# 0  Ketahui informasi pembagian #PPKM di wilayah J...          1
# 1  Tempat Ibadah di Wilayah PPKM Level 1 Boleh Be...          1
# 2  Juru bicara Satgas Covid-19, Wiku Adisasmito m...          1
# 3  Ketahui informasi pembagian #PPKM di wilayah J...          1
# 4  Kementerian Agama menerbitkan Surat Edaran Nom...          1

# %%
df = df.drop(['Date'], axis=1)

# %%
df
# Out:
#                 User                                              Tweet  \
# 0      pikobar_jabar  Ketahui informasi pembagian #PPKM di wilayah J...
# 1         inewsdotid  Tempat Ibadah di Wilayah PPKM Level 1 Boleh Be...
# 2          vdvc_talk  Juru bicara Satgas Covid-19, Wiku Adisasmito m...
# 3      pikobar_jabar  Ketahui informasi pembagian #PPKM di wilayah J...
# 4          tvOneNews  Kementerian Agama menerbitkan Surat Edaran Nom...
# ...              ...                                                ...
# 23639    bananabluff  noelle loses a bet to akarsha and it somehow e...
# 23640        Auqroix  they call her... weekeeshee...\n#butterflysoup...
# 23641        Auqroix  put out what you wanna see more of, amirite ga...
# 23642        Auqroix  i don't need anybody, i'm fine here on my own\...
# 23643   nindiiayudya  Selamat Siang sahabat online, nih aku sedikit ...
#
#        sentiment                                             step01
# 0              1  ketahui informasi pembagian di wilayah jabar b...
# 1              1  tempat ibadah di wilayah ppkm level   boleh be...
# 2              1  juru bicara satgas covid   wiku adisasmito men...
# 3              1  ketahui informasi pembagian di wilayah jabar b...
# 4              1  kementerian agama menerbitkan surat edaran nom...
# ...          ...                                                ...
# 23639          1  noelle loses bet to akarsha and it somehow end...
# 23640          1               they call her weekeeshee cocycpjwvef
# 23641          1  put out what you wanna see more of amirite gay...
# 23642          1  don need anybody fine here on my own but if ne...
# 23643          0  selamat siang sahabat online nih aku sedikit m...
#
# [23644 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23644 entries, 0 to 23643
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   User       23644 non-null  object
#  1   Tweet      23644 non-null  object
#  2   sentiment  23644 non-null  int64
#  3   step01     23644 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 739.0+ KB

# %% [markdown]
# # Preprocessing dataset
# saya akan pakai modul dari AMS 01-03

# %%
# !pip install ekphrasis
# Out:
# Requirement already satisfied: ekphrasis in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (0.5.4)
# Requirement already satisfied: termcolor in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from ekphrasis) (2.4.0)
# Requirement already satisfied: tqdm in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from ekphrasis) (4.66.2)
# Requirement already satisfied: colorama in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from ekphrasis) (0.4.6)
# Requirement already satisfied: ujson in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from ekphrasis) (5.9.0)
# Requirement already satisfied: matplotlib in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from ekphrasis) (3.8.3)
# Requirement already satisfied: nltk in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from ekphrasis) (3.8.1)
# Requirement already satisfied: ftfy in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from ekphrasis) (6.2.0)
# Requirement already satisfied: numpy in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from ekphrasis) (1.26.4)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from ftfy->ekphrasis) (0.2.13)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->ekphrasis) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->ekphrasis) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->ekphrasis) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->ekphrasis) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->ekphrasis) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->ekphrasis) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->ekphrasis) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->ekphrasis) (2.9.0.post0)
# Requirement already satisfied: click in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from nltk->ekphrasis) (8.1.7)
# Requirement already satisfied: joblib in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from nltk->ekphrasis) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from nltk->ekphrasis) (2023.12.25)
# Requirement already satisfied: six>=1.5 in c:\users\acer\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib->ekphrasis) (1.16.0)

# %%
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['email', 'percent', 'money', 'phone', 'user',
        'time', 'date', 'number'],
    # terms that will be annotated
    #annotate={"hashtag", "allcaps", "elongated", "repeated",'emphasis', 'censored'},
    annotate={"hashtag"},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated words
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)
# Out:
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...

# %%
# panggil ekphrasis

def bersih_data(text):
    return " ".join(text_processor.pre_process_doc(text))

# %%
# fungsi dari AMS 01-03. silakan cek bagaimana saya merubah menjadi fungsi

def non_ascii(text):
    return text.encode('ascii', 'replace').decode('ascii')

def remove_space_alzami(text):
    return " ".join(text.split())

def remove_emoji_alzami(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

def remove_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

def remove_tab2(text):
    return re.sub('\s+',' ',text)

def remove_rt(text):
    return text.replace('RT'," ")

def remove_mention(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

def remove_incomplete_url(text):
    return text.replace("http://", " ").replace("https://", " ")

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def change_stripe(text):
    return text.replace('-'," ")

def lower(text):
    return text.lower()

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def lower(text):
    return text.lower()

def remove_whitespace_LT(text):
    return text.strip()

def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") # don't remove hyphens
    pattern = r"[{}]".format(remove) # create the pattern
    return re.sub(pattern, "", text)

# %%
# hapus untuk <>
def remove_number_eks(text):
    return text.replace('<number>'," ")

def remove_angka(text):
    return re.sub(r"\d+", "", text) 

def remove_URL_eks(text):
    return text.replace('URL'," ").replace('url'," ")

def space_punctuation(text):
    return re.sub('(?<! )(?=[.,!?()])|(?<=[.,!?()])(?! )', r' ', text)

# %% [markdown]
# ## lakukan pembersihan dengan memanggil fungsi yang didefinisikan diatas

# %%
i = 0
final_string = []
s = ""
for text in df['Tweet'].values:
    filteredSentence = []
    EachReviewText = ""
    proc = remove_rt(text)
    proc = lower(proc)
    proc = change_stripe(proc)
    proc = remove_emoji_alzami(proc)
    proc = remove_tab(proc)
    proc = remove_tab2(proc)
    proc = non_ascii(proc)
    proc = remove_incomplete_url(proc)
    proc = remove_excessive_dot(proc)
    proc = remove_whitespace_LT(proc)
    proc = remove_whitespace_multiple(proc)
    proc = remove_single_char(proc)
    proc = space_punctuation(proc)
    proc = remove_punctuation(proc)
    proc = remove_space_alzami(proc)
    proc = bersih_data(proc)
    proc = remove_number_eks(proc)
    proc = remove_angka(proc) 
    proc = remove_URL_eks(proc)
    EachReviewText = proc
    final_string.append(EachReviewText)

# %%
df["step01"] = final_string

# %%
df.head(10)
# Out:
#              User                                              Tweet  \
# 0   pikobar_jabar  Ketahui informasi pembagian #PPKM di wilayah J...
# 1      inewsdotid  Tempat Ibadah di Wilayah PPKM Level 1 Boleh Be...
# 2       vdvc_talk  Juru bicara Satgas Covid-19, Wiku Adisasmito m...
# 3   pikobar_jabar  Ketahui informasi pembagian #PPKM di wilayah J...
# 4       tvOneNews  Kementerian Agama menerbitkan Surat Edaran Nom...
# 5    lampungpost_  Kapasitas tempat ibadah, termasuk masjid, yang...
# 6  akusehatklinik  Halo Sobat Sehat\n\nDengan adanya kondisi ini,...
# 7  matamilenialID  Mitigasi Penting untuk Cegah Penyebaran Varian...
# 8   lampungpostid  Sebanyak 5 (lima) kabupaten di Provinsi Lampun...
# 9       gemaposID  Komentar Satgas Penanganan Covid-19 Tentang Bu...
#
#    sentiment                                             step01
# 0          1  ketahui informasi pembagian di wilayah jabar b...
# 1          1  tempat ibadah di wilayah ppkm level   boleh be...
# 2          1  juru bicara satgas covid   wiku adisasmito men...
# 3          1  ketahui informasi pembagian di wilayah jabar b...
# 4          1  kementerian agama menerbitkan surat edaran nom...
# 5          1  kapasitas tempat ibadah termasuk masjid yang b...
# 6          1  halo sobat sehat dengan adanya kondisi ini pem...
# 7          1  mitigasi penting untuk cegah penyebaran varian...
# 8          1  sebanyak   lima kabupaten di provinsi lampung ...
# 9          1  komentar satgas penanganan covid   tentang buk...

# %% [markdown]
# ## hapus data kosong

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23644 entries, 0 to 23643
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   User       23644 non-null  object
#  1   Tweet      23644 non-null  object
#  2   sentiment  23644 non-null  int64
#  3   step01     23644 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 739.0+ KB

# %%
df_hapus = df[~df['step01'].str.contains(" ")]

# %%
df_hapus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1163 entries, 154 to 23637
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   User       1163 non-null   object
#  1   Tweet      1163 non-null   object
#  2   sentiment  1163 non-null   int64
#  3   step01     1163 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 45.4+ KB

# %%
df_hapus.head(10)
# Out:
#               User                                          Tweet  sentiment  \
# 154   mediaindopos    https://t.co/jzZ3PFEPhT\n\n#ppkm\n#jawabali          1
# 248       salsaaii                  https://t.co/zcr45lhM6h #ppkm          1
# 249       salsaaii                  https://t.co/SHQ8ANOOyW #ppkm          1
# 286    Macardianto                 #ppkm\nhttps://t.co/xpECW4SKKi          1
# 350  inosukesama17  #PPKMTEKANCOVID #ppkm https://t.co/vo94ekSjZd          1
# 351  inosukesama17  #PPKMTEKANCOVID #ppkm https://t.co/tlxVCOw8Mj          1
# 352  inosukesama17  #PPKMTEKANCOVID #ppkm https://t.co/inCCRKtRWr          1
# 353  inosukesama17  #PPKMTEKANCOVID #ppkm https://t.co/3mhnnp2L2S          1
# 354  inosukesama17  #PPKMTEKANCOVID #ppkm https://t.co/RxuQb2bMqy          1
# 355  inosukesama17  #PPKMTEKANCOVID #ppkm https://t.co/EajafS0aos          1
#
#            step01
# 154   cojzzpfepht
# 248     cozcrlhmh
# 249   coshqanooyw
# 286            co
# 350    covoeksjzd
# 351          cotl
# 352  coinccrktrwr
# 353     comhnnpls
# 354            co
# 355   coeajafsaos

# %%
df_new = df[~df.isin(df_hapus)].dropna()

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22481 entries, 0 to 23643
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   User       22481 non-null  object
#  1   Tweet      22481 non-null  object
#  2   sentiment  22481 non-null  float64
#  3   step01     22481 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 878.2+ KB

# %%
df_new
# Out:
#                 User                                              Tweet  \
# 0      pikobar_jabar  Ketahui informasi pembagian #PPKM di wilayah J...
# 1         inewsdotid  Tempat Ibadah di Wilayah PPKM Level 1 Boleh Be...
# 2          vdvc_talk  Juru bicara Satgas Covid-19, Wiku Adisasmito m...
# 3      pikobar_jabar  Ketahui informasi pembagian #PPKM di wilayah J...
# 4          tvOneNews  Kementerian Agama menerbitkan Surat Edaran Nom...
# ...              ...                                                ...
# 23639    bananabluff  noelle loses a bet to akarsha and it somehow e...
# 23640        Auqroix  they call her... weekeeshee...\n#butterflysoup...
# 23641        Auqroix  put out what you wanna see more of, amirite ga...
# 23642        Auqroix  i don't need anybody, i'm fine here on my own\...
# 23643   nindiiayudya  Selamat Siang sahabat online, nih aku sedikit ...
#
#        sentiment                                             step01
# 0            1.0  ketahui informasi pembagian di wilayah jabar b...
# 1            1.0  tempat ibadah di wilayah ppkm level   boleh be...
# 2            1.0  juru bicara satgas covid   wiku adisasmito men...
# 3            1.0  ketahui informasi pembagian di wilayah jabar b...
# 4            1.0  kementerian agama menerbitkan surat edaran nom...
# ...          ...                                                ...
# 23639        1.0  noelle loses bet to akarsha and it somehow end...
# 23640        1.0               they call her weekeeshee cocycpjwvef
# 23641        1.0  put out what you wanna see more of amirite gay...
# 23642        1.0  don need anybody fine here on my own but if ne...
# 23643        0.0  selamat siang sahabat online nih aku sedikit m...
#
# [22481 rows x 4 columns]

# %% [markdown]
# ## normalisasi kata slang menjadi kata baku

# %%
# token
import nltk
from nltk.tokenize import word_tokenize

# %%
def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
df_new['tokens'] = df['step01'].apply(word_tokenize_wrapper)

# %%
df_new.head(10)
# Out:
#              User                                              Tweet  \
# 0   pikobar_jabar  Ketahui informasi pembagian #PPKM di wilayah J...
# 1      inewsdotid  Tempat Ibadah di Wilayah PPKM Level 1 Boleh Be...
# 2       vdvc_talk  Juru bicara Satgas Covid-19, Wiku Adisasmito m...
# 3   pikobar_jabar  Ketahui informasi pembagian #PPKM di wilayah J...
# 4       tvOneNews  Kementerian Agama menerbitkan Surat Edaran Nom...
# 5    lampungpost_  Kapasitas tempat ibadah, termasuk masjid, yang...
# 6  akusehatklinik  Halo Sobat Sehat\n\nDengan adanya kondisi ini,...
# 7  matamilenialID  Mitigasi Penting untuk Cegah Penyebaran Varian...
# 8   lampungpostid  Sebanyak 5 (lima) kabupaten di Provinsi Lampun...
# 9       gemaposID  Komentar Satgas Penanganan Covid-19 Tentang Bu...
#
#    sentiment                                             step01  \
# 0        1.0  ketahui informasi pembagian di wilayah jabar b...
# 1        1.0  tempat ibadah di wilayah ppkm level   boleh be...
# 2        1.0  juru bicara satgas covid   wiku adisasmito men...
# 3        1.0  ketahui informasi pembagian di wilayah jabar b...
# 4        1.0  kementerian agama menerbitkan surat edaran nom...
# 5        1.0  kapasitas tempat ibadah termasuk masjid yang b...
# 6        1.0  halo sobat sehat dengan adanya kondisi ini pem...
# 7        1.0  mitigasi penting untuk cegah penyebaran varian...
# 8        1.0  sebanyak   lima kabupaten di provinsi lampung ...
# 9        1.0  komentar satgas penanganan covid   tentang buk...
#
#                                               tokens
# 0  [ketahui, informasi, pembagian, di, wilayah, j...
# 1  [tempat, ibadah, di, wilayah, ppkm, level, bol...
# 2  [juru, bicara, satgas, covid, wiku, adisasmito...
# 3  [ketahui, informasi, pembagian, di, wilayah, j...
# 4  [kementerian, agama, menerbitkan, surat, edara...
# 5  [kapasitas, tempat, ibadah, termasuk, masjid, ...
# 6  [halo, sobat, sehat, dengan, adanya, kondisi, ...
# 7  [mitigasi, penting, untuk, cegah, penyebaran, ...
# 8  [sebanyak, lima, kabupaten, di, provinsi, lamp...
# 9  [komentar, satgas, penanganan, covid, tentang,...

# %%
normalized_word = pd.read_csv('kamus_clean.csv')

# %%
normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_87540\2408214049.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] not in normalized_word_dict:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_87540\2408214049.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   normalized_word_dict[row[0]] = row[1]

# %%
df_new['final_tokens'] = df_new['tokens'].apply(normalized_term)

# %%
i=0
final_string_tokens = []
for text in df_new['final_tokens'].values:
    EachReviewText = ""
    EachReviewText = ' '.join(text)
    final_string_tokens.append(EachReviewText)

# %%
df_new["step02"] = final_string_tokens

# %%
df_new.head(10)
# Out:
#              User                                              Tweet  \
# 0   pikobar_jabar  Ketahui informasi pembagian #PPKM di wilayah J...
# 1      inewsdotid  Tempat Ibadah di Wilayah PPKM Level 1 Boleh Be...
# 2       vdvc_talk  Juru bicara Satgas Covid-19, Wiku Adisasmito m...
# 3   pikobar_jabar  Ketahui informasi pembagian #PPKM di wilayah J...
# 4       tvOneNews  Kementerian Agama menerbitkan Surat Edaran Nom...
# 5    lampungpost_  Kapasitas tempat ibadah, termasuk masjid, yang...
# 6  akusehatklinik  Halo Sobat Sehat\n\nDengan adanya kondisi ini,...
# 7  matamilenialID  Mitigasi Penting untuk Cegah Penyebaran Varian...
# 8   lampungpostid  Sebanyak 5 (lima) kabupaten di Provinsi Lampun...
# 9       gemaposID  Komentar Satgas Penanganan Covid-19 Tentang Bu...
#
#    sentiment                                             step01  \
# 0        1.0  ketahui informasi pembagian di wilayah jabar b...
# 1        1.0  tempat ibadah di wilayah ppkm level   boleh be...
# 2        1.0  juru bicara satgas covid   wiku adisasmito men...
# 3        1.0  ketahui informasi pembagian di wilayah jabar b...
# 4        1.0  kementerian agama menerbitkan surat edaran nom...
# 5        1.0  kapasitas tempat ibadah termasuk masjid yang b...
# 6        1.0  halo sobat sehat dengan adanya kondisi ini pem...
# 7        1.0  mitigasi penting untuk cegah penyebaran varian...
# 8        1.0  sebanyak   lima kabupaten di provinsi lampung ...
# 9        1.0  komentar satgas penanganan covid   tentang buk...
#
#                                               tokens  \
# 0  [ketahui, informasi, pembagian, di, wilayah, j...
# 1  [tempat, ibadah, di, wilayah, ppkm, level, bol...
# 2  [juru, bicara, satgas, covid, wiku, adisasmito...
# 3  [ketahui, informasi, pembagian, di, wilayah, j...
# 4  [kementerian, agama, menerbitkan, surat, edara...
# 5  [kapasitas, tempat, ibadah, termasuk, masjid, ...
# 6  [halo, sobat, sehat, dengan, adanya, kondisi, ...
# 7  [mitigasi, penting, untuk, cegah, penyebaran, ...
# 8  [sebanyak, lima, kabupaten, di, provinsi, lamp...
# 9  [komentar, satgas, penanganan, covid, tentang,...
#
#                                         final_tokens  \
# 0  [ketahui, informasi, pembagian, di, wilayah, j...
# 1  [tempat, ibadah, di, wilayah, ppkm, level, bol...
# 2  [juru, bicara, satgas, covid, wiku, adisasmito...
# 3  [ketahui, informasi, pembagian, di, wilayah, j...
# 4  [kementerian, agama, menerbitkan, surat, edara...
# 5  [kapasitas, tempat, ibadah, termasuk, masjid, ...
# 6  [halo, sobat, sehat, dengan, adanya, kondisi, ...
# 7  [mitigasi, penting, untuk, cegah, penyebaran, ...
# 8  [sebanyak, lima, kabupaten, di, provinsi, lamp...
# 9  [komentar, satgas, penanganan, covid, tentang,...
#
#                                               step02
# 0  ketahui informasi pembagian di wilayah jabar b...
# 1  tempat ibadah di wilayah ppkm level boleh berk...
# 2  juru bicara satgas covid wiku adisasmito menje...
# 3  ketahui informasi pembagian di wilayah jabar b...
# 4  kementerian agama menerbitkan surat edaran nom...
# 5  kapasitas tempat ibadah termasuk masjid yang b...
# 6  halo sobat sehat dengan adanya kondisi ini pem...
# 7  mitigasi penting untuk cegah penyebaran varian...
# 8  sebanyak lima kabupaten di provinsi lampung tu...
# 9  komentar satgas penanganan covid tentang buka ...

# %% [markdown]
# # simpan

# %%
df_new.to_csv('clean_dataset.csv',sep=";")
